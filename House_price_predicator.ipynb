# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitya-Dhagat/Machine-Learning/blob/Linear-Regression/House_price_predicator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **House price predictor**
# ## *Linear Regression Project 1*
#
# This is ML model that predicts house price the a candidate should deserve based upon the area of the house.
# This is example of Linear regression model.
#
# I have utilised kaggle daaset for this purposes. Link to the dataset : https://www.kaggle.com/code/ammar111/house-price-prediction-an-end-to-end-ml-project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import *

df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# %matplotlib inline
plt.xlabel('sq. ft')
plt.ylabel('price')
plt.scatter(df.LotArea,df.SalePrice, color = 'red', marker = '+')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([165136.067752])

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['LotArea']],df.SalePrice, test_size = 0.2)

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
reg.predict([[3000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([163157.93903414])

# %%
reg.coef_
reg.intercept_
ans = reg.coef_ * 3000 + reg.intercept_
print(ans)
# Out:
# [[165136.067752]]

# %%
test_score = reg.score(X_test,y_test)
print(test_score)
y_pred = reg.predict(X_test)
print(y_pred)
# Out:
# 0.03485465045590941
# [331442.61646939 173697.92768595 191929.32652971 182350.45371397
#  175307.23792308 182675.79266623 183125.3067911  174333.70456976
#  189234.72528391 185777.68847822 179524.22678519 159514.63946954
#  187491.30586035 183264.38298444 184689.91396609 179839.63172363
#  174333.70456976 189234.72528391 185261.11976013 218030.947814
#  170906.4698055  180107.85009649 180569.78173863 182529.26596254
#  176568.85767688 176866.87809116 179549.06181971 175170.6452332
#  168373.2962841  186398.56434131 189719.00845712 182829.76988027
#  187160.99990119 197104.94772443 184555.80477966 180751.07749065
#  182161.70745159 175078.75560546 169831.11281063 213466.26846857
#  189165.18718724 179921.58733756 161439.35464511 178101.17930698
#  195525.43952873 184213.08130324 184160.92773074 171651.52084121
#  192470.73028233 164983.31407163 176581.27519414 173588.65353405
#  185390.26193966 550584.47760203 181138.50402922 185961.4677337
# ...

# %%
# %matplotlib inline
plt.xlabel('sq. ft', size=20)
plt.ylabel('price',size=20)
plt.scatter(df.LotArea,df.SalePrice, color = 'red', marker = '+')
plt.plot(X_test,y_pred,color = 'blue')
plt.show()
